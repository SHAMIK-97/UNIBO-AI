# %%
# !pip install kora -q
from kora import drive
drive.link_nbs()
# Out:
#      |████████████████████████████████| 57 kB 2.8 MB/s
# Mounted at /content/drive

# %%
from dataset_generator import getDataset
# Out:
# importing Jupyter notebook from /nbs/dataset_generator.ipynb

# %% [markdown]
# Below the train set, train blur set, test set and test blur set is generated

# %%
(X_train_Blur,X_train),(X_test_Blur,X_test) = getDataset()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 11s 0us/step
# 170508288/170498071 [==============================] - 11s 0us/step

# %% [markdown]
# Below are the dimensions of the corresponding datasets.
# Train blur set : (50000, 32, 32, 3)
# train set : (50000, 32, 32, 3)
# test set blur: (10000, 32, 32, 3)
# test set : (10000, 32, 32, 3)

# %%
print(X_train_Blur.shape)
print(X_train.shape)
print(X_test_Blur.shape)
print(X_test.shape)

X_test
# Out:
# (50000, 32, 32, 3)
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)
# (10000, 32, 32, 3)
# array([[[[0.61960784, 0.43921569, 0.19215686],
#          [0.62352941, 0.43529412, 0.18431373],
#          [0.64705882, 0.45490196, 0.2       ],
#          ...,
#          [0.5372549 , 0.37254902, 0.14117647],
#          [0.49411765, 0.35686275, 0.14117647],
#          [0.45490196, 0.33333333, 0.12941176]],
#
#         [[0.59607843, 0.43921569, 0.2       ],
#          [0.59215686, 0.43137255, 0.15686275],
#          [0.62352941, 0.44705882, 0.17647059],
#          ...,
#          [0.53333333, 0.37254902, 0.12156863],
#          [0.49019608, 0.35686275, 0.1254902 ],
#          [0.46666667, 0.34509804, 0.13333333]],
#
#         [[0.59215686, 0.43137255, 0.18431373],
#          [0.59215686, 0.42745098, 0.12941176],
#          [0.61960784, 0.43529412, 0.14117647],
#          ...,
#          [0.54509804, 0.38431373, 0.13333333],
#          [0.50980392, 0.37254902, 0.13333333],
#          [0.47058824, 0.34901961, 0.12941176]],
#
#         ...,
#
#         [[0.26666667, 0.48627451, 0.69411765],
#          [0.16470588, 0.39215686, 0.58039216],
#          [0.12156863, 0.34509804, 0.5372549 ],
#          ...,
#          [0.14901961, 0.38039216, 0.57254902],
#          [0.05098039, 0.25098039, 0.42352941],
#          [0.15686275, 0.33333333, 0.49803922]],
#
#         [[0.23921569, 0.45490196, 0.65882353],
#          [0.19215686, 0.4       , 0.58039216],
#          [0.1372549 , 0.33333333, 0.51764706],
#          ...,
#          [0.10196078, 0.32156863, 0.50980392],
#          [0.11372549, 0.32156863, 0.49411765],
#          [0.07843137, 0.25098039, 0.41960784]],
#
#         [[0.21176471, 0.41960784, 0.62745098],
#          [0.21960784, 0.41176471, 0.58431373],
#          [0.17647059, 0.34901961, 0.51764706],
#          ...,
#          [0.09411765, 0.30196078, 0.48627451],
#          [0.13333333, 0.32941176, 0.50588235],
#          [0.08235294, 0.2627451 , 0.43137255]]],
#
#
#        [[[0.92156863, 0.92156863, 0.92156863],
#          [0.90588235, 0.90588235, 0.90588235],
#          [0.90980392, 0.90980392, 0.90980392],
#          ...,
#          [0.91372549, 0.91372549, 0.91372549],
#          [0.91372549, 0.91372549, 0.91372549],
#          [0.90980392, 0.90980392, 0.90980392]],
#
#          [0.10588235, 0.10196078, 0.10196078]]]])

# %%
import matplotlib.pyplot as plt
from tensorflow.keras import layers
from tensorflow.keras.models import Model
import numpy as np

# This function displays 10 random images from each of the supplied arrays

def display(array1, array2):
    """
    Displays ten random images from each one of the supplied arrays.
    """

    n = 10

    indices = np.random.randint(len(array1), size=n)
    images1 = array1[indices, :]
    images2 = array2[indices, :]

    plt.figure(figsize=(20, 4))
    for i, (image1, image2) in enumerate(zip(images1, images2)):
        ax = plt.subplot(2, n, i + 1)
        plt.imshow(image1.reshape(32, 32,3))
        plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        ax = plt.subplot(2, n, i + 1 + n)
        plt.imshow(image2.reshape(32, 32,3))
        plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

    plt.show()

# %%
# Display the train data and a version of it with added noise and blur
display(X_train, X_train_Blur)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# Below API model actually deblurs the image. The model architecture is taken from DBSR model architecture (more deeper version of DBSRCNN model with extra 3 convolution layers).It has total 8 layers with total parameters 351,043. The first layer consists of 2D convolutions of kernel size=9, number of filters is 32.The ﬁrst layer is feature extraction to compute the low-level features.
# The third layer merges features from the ﬁrst twolayers creating a merged vector with low-level and enhanced features.
#
# The merge operation is actually concatenation of 2 previous outputs.
#
# After the concatenation layer, features are processed by 3 more layers before mapping it for final mapping.
#
# https://ieeexplore.ieee.org/document/8903000

# %%
from tensorflow.keras.optimizers import Adam
from keras.callbacks import LearningRateScheduler

def DBSRCNN(input_shape,output_shape=None):
  x = layers.Input(shape = input_shape)
  c1 = layers.Convolution2D(64, (9, 9), padding="same", kernel_initializer="he_normal", activation="relu")(x)
  c2 = layers.Convolution2D(32, (5, 5), padding="same", kernel_initializer="he_normal", activation="relu")(c1)
  m=   layers.concatenate([c1, c2])
  c3 = layers.Convolution2D(64, (5, 5), padding="same", kernel_initializer="he_normal", activation="relu")(m)
  c4 = layers.Convolution2D(32, (5, 5), padding="same", kernel_initializer="he_normal", activation="relu")(c3)
  c5 = layers.Convolution2D(32, (5, 5), padding="same", kernel_initializer="he_normal", activation="relu")(c4)
  c6 = layers.Convolution2D(32, (5, 5), padding="same", kernel_initializer="he_normal", activation="relu")(c5)
  c7 = layers.Convolution2D(32, (5, 5), padding="same", kernel_initializer="he_normal", activation="relu")(c6)
  c8 = layers.Convolution2D(3, (5, 5), padding="same", kernel_initializer="he_normal")(c7)
  deblured = Model(inputs = x, outputs = c8)
  return deblured

# %% [markdown]
# The below function is the schedular. It helps to update the learning rate of the optimizer while training.

# %%
import math

def step_decay(epoch):
	initial_lrate = 0.001
	drop = 0.1
	epochs_drop = 20
	lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
	return lrate

# %% [markdown]
# Here we are dynamically updating the learning rate while training. mean squared error loss function is used.

# %%
first_model = DBSRCNN((32,32,3))

##compile
first_model.compile(optimizer=Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-8),loss='mean_squared_error', metrics=['mse','accuracy'])

first_model.summary()

lrate = LearningRateScheduler(step_decay)
callbacks_list = [lrate]
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 32, 32, 64)   15616       ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 32, 32, 32)   51232       ['conv2d[0][0]']
#
#  concatenate (Concatenate)      (None, 32, 32, 96)   0           ['conv2d[0][0]',
#                                                                   'conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 64)   153664      ['concatenate[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 32)   51232       ['conv2d_2[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 32)   25632       ['conv2d_3[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 32)   25632       ['conv2d_4[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 32)   25632       ['conv2d_5[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 3)    2403        ['conv2d_6[0][0]']
#
# ==================================================================================================
# Total params: 351,043
# Trainable params: 351,043
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# Here we are training the deblurring model with input as blurred train set and output as the x_train set. For validation we are using blurred X test set and X_test set.

# %%
hist = first_model.fit(
    x=X_train_Blur,
    y=X_train,
    epochs=70,
    batch_size=64,
    shuffle=True,
    callbacks = [lrate],
    validation_data=(X_test_Blur, X_test))
# Out:
# Epoch 1/70
# 782/782 [==============================] - 35s 29ms/step - loss: 0.0115 - mse: 0.0115 - accuracy: 0.6758 - val_loss: 0.0052 - val_mse: 0.0052 - val_accuracy: 0.7491 - lr: 0.0010
# Epoch 2/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0043 - mse: 0.0043 - accuracy: 0.7788 - val_loss: 0.0039 - val_mse: 0.0039 - val_accuracy: 0.7989 - lr: 0.0010
# Epoch 3/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0039 - mse: 0.0039 - accuracy: 0.7917 - val_loss: 0.0038 - val_mse: 0.0038 - val_accuracy: 0.7827 - lr: 0.0010
# Epoch 4/70
# 782/782 [==============================] - 22s 29ms/step - loss: 0.0037 - mse: 0.0037 - accuracy: 0.8031 - val_loss: 0.0036 - val_mse: 0.0036 - val_accuracy: 0.7835 - lr: 0.0010
# Epoch 5/70
# 782/782 [==============================] - 22s 29ms/step - loss: 0.0036 - mse: 0.0036 - accuracy: 0.8058 - val_loss: 0.0034 - val_mse: 0.0034 - val_accuracy: 0.8065 - lr: 0.0010
# Epoch 6/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0035 - mse: 0.0035 - accuracy: 0.8077 - val_loss: 0.0037 - val_mse: 0.0037 - val_accuracy: 0.8260 - lr: 0.0010
# Epoch 7/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0034 - mse: 0.0034 - accuracy: 0.8102 - val_loss: 0.0031 - val_mse: 0.0031 - val_accuracy: 0.8242 - lr: 0.0010
# Epoch 8/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0033 - mse: 0.0033 - accuracy: 0.8147 - val_loss: 0.0032 - val_mse: 0.0032 - val_accuracy: 0.8373 - lr: 0.0010
# Epoch 9/70
# 782/782 [==============================] - 22s 29ms/step - loss: 0.0032 - mse: 0.0032 - accuracy: 0.8150 - val_loss: 0.0031 - val_mse: 0.0031 - val_accuracy: 0.8341 - lr: 0.0010
# Epoch 10/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0031 - mse: 0.0031 - accuracy: 0.8194 - val_loss: 0.0030 - val_mse: 0.0030 - val_accuracy: 0.8369 - lr: 0.0010
# Epoch 11/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0031 - mse: 0.0031 - accuracy: 0.8187 - val_loss: 0.0031 - val_mse: 0.0031 - val_accuracy: 0.8188 - lr: 0.0010
# Epoch 12/70
# 782/782 [==============================] - 22s 29ms/step - loss: 0.0031 - mse: 0.0031 - accuracy: 0.8193 - val_loss: 0.0030 - val_mse: 0.0030 - val_accuracy: 0.8168 - lr: 0.0010
# Epoch 13/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0029 - mse: 0.0029 - accuracy: 0.8238 - val_loss: 0.0028 - val_mse: 0.0028 - val_accuracy: 0.8322 - lr: 0.0010
# Epoch 14/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0029 - mse: 0.0029 - accuracy: 0.8229 - val_loss: 0.0030 - val_mse: 0.0030 - val_accuracy: 0.8313 - lr: 0.0010
# Epoch 15/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0029 - mse: 0.0029 - accuracy: 0.8247 - val_loss: 0.0030 - val_mse: 0.0030 - val_accuracy: 0.8513 - lr: 0.0010
# Epoch 16/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0028 - mse: 0.0028 - accuracy: 0.8269 - val_loss: 0.0028 - val_mse: 0.0028 - val_accuracy: 0.8206 - lr: 0.0010
# Epoch 17/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0029 - mse: 0.0029 - accuracy: 0.8207 - val_loss: 0.0029 - val_mse: 0.0029 - val_accuracy: 0.7713 - lr: 0.0010
# Epoch 18/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0028 - mse: 0.0028 - accuracy: 0.8265 - val_loss: 0.0027 - val_mse: 0.0027 - val_accuracy: 0.8205 - lr: 0.0010
# Epoch 19/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0028 - mse: 0.0028 - accuracy: 0.8286 - val_loss: 0.0029 - val_mse: 0.0029 - val_accuracy: 0.8446 - lr: 0.0010
# Epoch 20/70
# 782/782 [==============================] - 22s 29ms/step - loss: 0.0025 - mse: 0.0025 - accuracy: 0.8489 - val_loss: 0.0025 - val_mse: 0.0025 - val_accuracy: 0.8507 - lr: 1.0000e-04
# Epoch 21/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0025 - mse: 0.0025 - accuracy: 0.8498 - val_loss: 0.0025 - val_mse: 0.0025 - val_accuracy: 0.8517 - lr: 1.0000e-04
# Epoch 22/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0025 - mse: 0.0025 - accuracy: 0.8501 - val_loss: 0.0025 - val_mse: 0.0025 - val_accuracy: 0.8493 - lr: 1.0000e-04
# Epoch 23/70
# 782/782 [==============================] - 22s 29ms/step - loss: 0.0025 - mse: 0.0025 - accuracy: 0.8507 - val_loss: 0.0025 - val_mse: 0.0025 - val_accuracy: 0.8537 - lr: 1.0000e-04
# Epoch 24/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0025 - mse: 0.0025 - accuracy: 0.8510 - val_loss: 0.0025 - val_mse: 0.0025 - val_accuracy: 0.8518 - lr: 1.0000e-04
# Epoch 25/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0025 - mse: 0.0025 - accuracy: 0.8512 - val_loss: 0.0025 - val_mse: 0.0025 - val_accuracy: 0.8527 - lr: 1.0000e-04
# Epoch 26/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0025 - mse: 0.0025 - accuracy: 0.8518 - val_loss: 0.0025 - val_mse: 0.0025 - val_accuracy: 0.8548 - lr: 1.0000e-04
# Epoch 27/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0025 - mse: 0.0025 - accuracy: 0.8519 - val_loss: 0.0025 - val_mse: 0.0025 - val_accuracy: 0.8473 - lr: 1.0000e-04
# Epoch 28/70
# 782/782 [==============================] - 22s 29ms/step - loss: 0.0025 - mse: 0.0025 - accuracy: 0.8522 - val_loss: 0.0025 - val_mse: 0.0025 - val_accuracy: 0.8585 - lr: 1.0000e-04
# Epoch 29/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0025 - mse: 0.0025 - accuracy: 0.8526 - val_loss: 0.0025 - val_mse: 0.0025 - val_accuracy: 0.8565 - lr: 1.0000e-04
# Epoch 30/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0025 - mse: 0.0025 - accuracy: 0.8530 - val_loss: 0.0025 - val_mse: 0.0025 - val_accuracy: 0.8546 - lr: 1.0000e-04
# Epoch 31/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0025 - mse: 0.0025 - accuracy: 0.8531 - val_loss: 0.0025 - val_mse: 0.0025 - val_accuracy: 0.8408 - lr: 1.0000e-04
# Epoch 32/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0025 - mse: 0.0025 - accuracy: 0.8533 - val_loss: 0.0025 - val_mse: 0.0025 - val_accuracy: 0.8516 - lr: 1.0000e-04
# Epoch 33/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8536 - val_loss: 0.0025 - val_mse: 0.0025 - val_accuracy: 0.8605 - lr: 1.0000e-04
# Epoch 34/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8537 - val_loss: 0.0025 - val_mse: 0.0025 - val_accuracy: 0.8564 - lr: 1.0000e-04
# Epoch 35/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8538 - val_loss: 0.0025 - val_mse: 0.0025 - val_accuracy: 0.8602 - lr: 1.0000e-04
# Epoch 36/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8540 - val_loss: 0.0025 - val_mse: 0.0025 - val_accuracy: 0.8588 - lr: 1.0000e-04
# Epoch 37/70
# 782/782 [==============================] - 22s 29ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8543 - val_loss: 0.0025 - val_mse: 0.0025 - val_accuracy: 0.8492 - lr: 1.0000e-04
# Epoch 38/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8545 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8601 - lr: 1.0000e-04
# Epoch 39/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8545 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8568 - lr: 1.0000e-04
# Epoch 40/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8557 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8565 - lr: 1.0000e-05
# Epoch 41/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8558 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8569 - lr: 1.0000e-05
# Epoch 42/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8558 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8571 - lr: 1.0000e-05
# Epoch 43/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8558 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8574 - lr: 1.0000e-05
# Epoch 44/70
# 782/782 [==============================] - 22s 29ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8558 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8556 - lr: 1.0000e-05
# Epoch 45/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8559 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8558 - lr: 1.0000e-05
# Epoch 46/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8559 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8559 - lr: 1.0000e-05
# Epoch 47/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8559 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8573 - lr: 1.0000e-05
# Epoch 48/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8560 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8568 - lr: 1.0000e-05
# Epoch 49/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8560 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8565 - lr: 1.0000e-05
# Epoch 50/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8560 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8579 - lr: 1.0000e-05
# Epoch 51/70
# 782/782 [==============================] - 22s 29ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8561 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8577 - lr: 1.0000e-05
# Epoch 52/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8561 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8571 - lr: 1.0000e-05
# Epoch 53/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8561 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8572 - lr: 1.0000e-05
# Epoch 54/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8561 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8576 - lr: 1.0000e-05
# Epoch 55/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8562 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8588 - lr: 1.0000e-05
# Epoch 56/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8562 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8587 - lr: 1.0000e-05
# Epoch 57/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8562 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8573 - lr: 1.0000e-05
# Epoch 58/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8563 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8571 - lr: 1.0000e-05
# Epoch 59/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8563 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8564 - lr: 1.0000e-05
# Epoch 60/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8564 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8576 - lr: 1.0000e-06
# Epoch 61/70
# 782/782 [==============================] - 22s 29ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8564 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8573 - lr: 1.0000e-06
# Epoch 62/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8564 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8573 - lr: 1.0000e-06
# Epoch 63/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8564 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8572 - lr: 1.0000e-06
# Epoch 64/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8564 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8576 - lr: 1.0000e-06
# Epoch 65/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8564 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8574 - lr: 1.0000e-06
# Epoch 66/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8564 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8570 - lr: 1.0000e-06
# Epoch 67/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8564 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8581 - lr: 1.0000e-06
# Epoch 68/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8564 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8574 - lr: 1.0000e-06
# Epoch 69/70
# 782/782 [==============================] - 22s 29ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8564 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8577 - lr: 1.0000e-06
# Epoch 70/70
# 782/782 [==============================] - 22s 28ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8564 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8573 - lr: 1.0000e-06

# %% [markdown]
# weights of deblur model is saved. And a comparison of picture of test blurred set pictures and the predicted pictures of model is shown.
#
# We can observe there is a deblurring of the pictures occured.

# %%
# Saving the model and it weights seperately
first_model.save('/weights/deblur.h5')
first_model.save_weights('/weights/deblur_weight.h5')


predictions = first_model.predict(X_test_Blur)
display(X_test_Blur, predictions)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# The mse value of the deblur model is shown below

# %% [markdown]
# We can observe that the image quality is improved slightly.
#
# The MSE value of the model is 0.0024

# %%
first_model.evaluate(X_test_Blur,X_test)
# Out:
# 313/313 [==============================] - 2s 7ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8573
# [0.0024140432942658663, 0.0024140432942658663, 0.8572975397109985]

# %% [markdown]
# The mse and loss value curve is shown with train and validation set.
# The model is not overfitting or underfitting.

# %% [markdown]
# We are plotting the mse , loss and accuracy against the epoch value of the train and validation set

# %%
import matplotlib.pyplot as plt

def plot_history(model_history,keys):
    m,val_m = keys
    plt.plot(model_history.history[m])
    plt.plot(model_history.history[val_m])
    plt.ylabel(m)
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()

plot_history(hist,['mse','val_mse'])
plot_history(hist,['loss','val_loss'])
plot_history(hist,['accuracy','val_accuracy'])

# %% [markdown]
# We can see the model is neither overfitting nor underfitting.

# %% [markdown]
# ########################------------------------------------############

# %% [markdown]
# Below is the model to denoise the image. It is a DnCNN model. It has 19 layers. Total parameters are 561283.
#
# The idea behind denoising the image :
#
# let the input image is y which is noisy.
# So y = x + v, where x is the denoised image and v is the noise.
#
# So, x = y-v we will get the denoised image.
#
# In the below model, The first layer and the second layer captures the feature of the noisy image, the subsequent 15 Convolutional layers with filter size 3 and number of filters are 64 captures the noise.
#
# The last layer does the subtraction.
#
# https://ieeexplore.ieee.org/document/7839189

# %%
from keras.models import load_model
from keras.layers import  Input,Conv2D,BatchNormalization,Activation,Lambda,Subtract
#from tensorflow.keras.callbacks import EarlyStopping


def DnCNN():
    
    inpt = Input(shape=(32,32,3))
    # 1st layer, Conv+relu
    x = Conv2D(filters=64, kernel_size=(3,3), strides=(1,1), padding='same')(inpt)
    x = Activation('relu')(x)
    # 15 layers, Conv+BN+relu
    for i in range(15):
        x = Conv2D(filters=64, kernel_size=(3,3), strides=(1,1), padding='same')(x)
        x = BatchNormalization(axis=-1, epsilon=1e-3)(x)
        x = Activation('relu')(x)   
    # last layer, Conv
    x = Conv2D(filters=3, kernel_size=(3,3), strides=(1,1), padding='same')(x)
    x = Subtract()([inpt, x])   # input - noise
    model = Model(inputs=inpt, outputs=x)
    
    return model


denoised = DnCNN()
denoised.summary()
##Compile
denoised.compile(optimizer='adam' , loss='mse', metrics=['mse','accuracy'])
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 64)   1792        ['input_2[0][0]']
#
#  activation (Activation)        (None, 32, 32, 64)   0           ['conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 64)   36928       ['activation[0][0]']
#
#  batch_normalization (BatchNorm  (None, 32, 32, 64)  256         ['conv2d_9[0][0]']
#  alization)
#
#  activation_1 (Activation)      (None, 32, 32, 64)   0           ['batch_normalization[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 64)   36928       ['activation_1[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_10[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 32, 32, 64)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 64)   36928       ['activation_2[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_11[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 32, 32, 64)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 64)   36928       ['activation_3[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_12[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 32, 32, 64)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 64)   36928       ['activation_4[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_13[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 32, 32, 64)   0           ['batch_normalization_4[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 32, 32, 64)   36928       ['activation_5[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_14[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 32, 32, 64)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 64)   36928       ['activation_6[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_15[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 32, 32, 64)   0           ['batch_normalization_6[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 32, 32, 64)   36928       ['activation_7[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_16[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 32, 32, 64)   0           ['batch_normalization_7[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 32, 32, 64)   36928       ['activation_8[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_17[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 32, 32, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 32, 32, 64)   36928       ['activation_9[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_18[0][0]']
#  rmalization)
#
#  activation_10 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_9[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 32, 32, 64)   36928       ['activation_10[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 64)  256         ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_10[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 32, 32, 64)   36928       ['activation_11[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 64)  256         ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_11[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 32, 32, 64)   36928       ['activation_12[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 32, 32, 64)  256         ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_12[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 32, 32, 64)   36928       ['activation_13[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 32, 32, 64)  256         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_13[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 32, 32, 64)   36928       ['activation_14[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 32, 32, 64)  256         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_14[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 32, 32, 3)    1731        ['activation_15[0][0]']
#
#  subtract (Subtract)            (None, 32, 32, 3)    0           ['input_2[0][0]',
#                                                                   'conv2d_24[0][0]']
#
# ==================================================================================================
# Total params: 561,283
# Trainable params: 559,363
# Non-trainable params: 1,920
# __________________________________________________________________________________________________

# %% [markdown]
# Here we are training the deblurring model with input as blurred train set and output as the x_train set. For validation we are using blurred X test set and X_test set.

# %%
denoised.fit(
    x=X_train_Blur,
    y=X_train,
    epochs=80,
    batch_size=32,
    shuffle=True,
    validation_data=(X_test_Blur, X_test),
)
# Out:
# Epoch 1/80
# 1563/1563 [==============================] - 46s 28ms/step - loss: 0.0065 - mse: 0.0065 - accuracy: 0.7700 - val_loss: 0.0036 - val_mse: 0.0036 - val_accuracy: 0.7798
# Epoch 2/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0034 - mse: 0.0034 - accuracy: 0.7785 - val_loss: 0.0033 - val_mse: 0.0033 - val_accuracy: 0.7847
# Epoch 3/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0031 - mse: 0.0031 - accuracy: 0.7796 - val_loss: 0.0030 - val_mse: 0.0030 - val_accuracy: 0.7850
# Epoch 4/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0030 - mse: 0.0030 - accuracy: 0.7799 - val_loss: 0.0031 - val_mse: 0.0031 - val_accuracy: 0.7621
# Epoch 5/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0029 - mse: 0.0029 - accuracy: 0.7798 - val_loss: 0.0028 - val_mse: 0.0028 - val_accuracy: 0.7807
# Epoch 6/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0028 - mse: 0.0028 - accuracy: 0.7812 - val_loss: 0.0028 - val_mse: 0.0028 - val_accuracy: 0.7837
# Epoch 7/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0027 - mse: 0.0027 - accuracy: 0.7816 - val_loss: 0.0029 - val_mse: 0.0029 - val_accuracy: 0.7852
# Epoch 8/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0027 - mse: 0.0027 - accuracy: 0.7831 - val_loss: 0.0028 - val_mse: 0.0028 - val_accuracy: 0.7835
# Epoch 9/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0026 - mse: 0.0026 - accuracy: 0.7849 - val_loss: 0.0029 - val_mse: 0.0029 - val_accuracy: 0.7865
# Epoch 10/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0025 - mse: 0.0025 - accuracy: 0.7875 - val_loss: 0.0026 - val_mse: 0.0026 - val_accuracy: 0.7973
# Epoch 11/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0025 - mse: 0.0025 - accuracy: 0.7903 - val_loss: 0.0025 - val_mse: 0.0025 - val_accuracy: 0.7915
# Epoch 12/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.7956 - val_loss: 0.0025 - val_mse: 0.0025 - val_accuracy: 0.7989
# Epoch 13/80
# 1563/1563 [==============================] - 43s 27ms/step - loss: 0.0025 - mse: 0.0025 - accuracy: 0.7992 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8053
# Epoch 14/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0026 - mse: 0.0026 - accuracy: 0.8003 - val_loss: 0.0026 - val_mse: 0.0026 - val_accuracy: 0.7941
# Epoch 15/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8017 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8011
# Epoch 16/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8032 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8016
# Epoch 17/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8039 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8037
# Epoch 18/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0023 - mse: 0.0023 - accuracy: 0.8042 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8086
# Epoch 19/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0023 - mse: 0.0023 - accuracy: 0.8048 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8067
# Epoch 20/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0023 - mse: 0.0023 - accuracy: 0.8052 - val_loss: 0.0025 - val_mse: 0.0025 - val_accuracy: 0.8030
# Epoch 21/80
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.0023 - mse: 0.0023 - accuracy: 0.8053 - val_loss: 0.0037 - val_mse: 0.0037 - val_accuracy: 0.7972
# Epoch 22/80
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.0023 - mse: 0.0023 - accuracy: 0.8057 - val_loss: 0.0025 - val_mse: 0.0025 - val_accuracy: 0.8069
# Epoch 23/80
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.0023 - mse: 0.0023 - accuracy: 0.8063 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8100
# Epoch 24/80
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.0023 - mse: 0.0023 - accuracy: 0.8065 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8070
# Epoch 25/80
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.0023 - mse: 0.0023 - accuracy: 0.8067 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8081
# Epoch 26/80
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.0023 - mse: 0.0023 - accuracy: 0.8057 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8070
# Epoch 27/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0023 - mse: 0.0023 - accuracy: 0.8070 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8106
# Epoch 28/80
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.0022 - mse: 0.0022 - accuracy: 0.8071 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8068
# Epoch 29/80
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.0022 - mse: 0.0022 - accuracy: 0.8072 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8081
# Epoch 30/80
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.0022 - mse: 0.0022 - accuracy: 0.8070 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8053
# Epoch 31/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0022 - mse: 0.0022 - accuracy: 0.8074 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8081
# Epoch 32/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0025 - mse: 0.0025 - accuracy: 0.8031 - val_loss: 0.0025 - val_mse: 0.0025 - val_accuracy: 0.8050
# Epoch 33/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0023 - mse: 0.0023 - accuracy: 0.8057 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8088
# Epoch 34/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0022 - mse: 0.0022 - accuracy: 0.8068 - val_loss: 0.0024 - val_mse: 0.0024 - val_accuracy: 0.8091
# Epoch 35/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0022 - mse: 0.0022 - accuracy: 0.8072 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8063
# Epoch 36/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0022 - mse: 0.0022 - accuracy: 0.8072 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8090
# Epoch 37/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0022 - mse: 0.0022 - accuracy: 0.8073 - val_loss: 0.1564 - val_mse: 0.1564 - val_accuracy: 0.7560
# Epoch 38/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0022 - mse: 0.0022 - accuracy: 0.8070 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8077
# Epoch 39/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0022 - mse: 0.0022 - accuracy: 0.8074 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8083
# Epoch 40/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0022 - mse: 0.0022 - accuracy: 0.8075 - val_loss: 0.0069 - val_mse: 0.0069 - val_accuracy: 0.7773
# Epoch 41/80
# 1563/1563 [==============================] - 43s 27ms/step - loss: 0.0023 - mse: 0.0023 - accuracy: 0.8053 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8091
# Epoch 42/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0022 - mse: 0.0022 - accuracy: 0.8069 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8082
# Epoch 43/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0022 - mse: 0.0022 - accuracy: 0.8076 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8071
# Epoch 44/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0022 - mse: 0.0022 - accuracy: 0.8077 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8120
# Epoch 45/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0022 - mse: 0.0022 - accuracy: 0.8077 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8086
# Epoch 46/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0022 - mse: 0.0022 - accuracy: 0.8077 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8078
# Epoch 47/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0022 - mse: 0.0022 - accuracy: 0.8079 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8100
# Epoch 48/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0022 - mse: 0.0022 - accuracy: 0.8081 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8072
# Epoch 49/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0022 - mse: 0.0022 - accuracy: 0.8081 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8095
# Epoch 50/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0022 - mse: 0.0022 - accuracy: 0.8082 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8096
# Epoch 51/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0022 - mse: 0.0022 - accuracy: 0.8082 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8092
# Epoch 52/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0022 - mse: 0.0022 - accuracy: 0.8083 - val_loss: 0.0022 - val_mse: 0.0022 - val_accuracy: 0.8088
# Epoch 53/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0022 - mse: 0.0022 - accuracy: 0.8082 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8082
# Epoch 54/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0022 - mse: 0.0022 - accuracy: 0.8083 - val_loss: 0.0022 - val_mse: 0.0022 - val_accuracy: 0.8093
# Epoch 55/80
# 1563/1563 [==============================] - 43s 27ms/step - loss: 0.0022 - mse: 0.0022 - accuracy: 0.8081 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8090
# Epoch 56/80
# 1563/1563 [==============================] - 43s 27ms/step - loss: 0.0022 - mse: 0.0022 - accuracy: 0.8086 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8120
# Epoch 57/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0021 - mse: 0.0021 - accuracy: 0.8087 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8083
# Epoch 58/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0021 - mse: 0.0021 - accuracy: 0.8086 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8084
# Epoch 59/80
# 1563/1563 [==============================] - 43s 27ms/step - loss: 0.0021 - mse: 0.0021 - accuracy: 0.8086 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8080
# Epoch 60/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0021 - mse: 0.0021 - accuracy: 0.8086 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8110
# Epoch 61/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0021 - mse: 0.0021 - accuracy: 0.8087 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8102
# Epoch 62/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0021 - mse: 0.0021 - accuracy: 0.8085 - val_loss: 0.0022 - val_mse: 0.0022 - val_accuracy: 0.8081
# Epoch 63/80
# 1563/1563 [==============================] - 43s 27ms/step - loss: 0.0021 - mse: 0.0021 - accuracy: 0.8087 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8121
# Epoch 64/80
# 1563/1563 [==============================] - 43s 27ms/step - loss: 0.0021 - mse: 0.0021 - accuracy: 0.8087 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8112
# Epoch 65/80
# 1563/1563 [==============================] - 43s 28ms/step - loss: 0.0021 - mse: 0.0021 - accuracy: 0.8088 - val_loss: 0.0022 - val_mse: 0.0022 - val_accuracy: 0.8105
# Epoch 66/80
# 1563/1563 [==============================] - 43s 27ms/step - loss: 0.0021 - mse: 0.0021 - accuracy: 0.8088 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8085
# Epoch 67/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0022 - mse: 0.0022 - accuracy: 0.8084 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8095
# Epoch 68/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0021 - mse: 0.0021 - accuracy: 0.8089 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8135
# Epoch 69/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0021 - mse: 0.0021 - accuracy: 0.8090 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8078
# Epoch 70/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0021 - mse: 0.0021 - accuracy: 0.8087 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8119
# Epoch 71/80
# 1563/1563 [==============================] - 43s 27ms/step - loss: 0.0021 - mse: 0.0021 - accuracy: 0.8090 - val_loss: 0.0022 - val_mse: 0.0022 - val_accuracy: 0.8119
# Epoch 72/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0021 - mse: 0.0021 - accuracy: 0.8090 - val_loss: 0.0022 - val_mse: 0.0022 - val_accuracy: 0.8094
# Epoch 73/80
# 1563/1563 [==============================] - 43s 27ms/step - loss: 0.0021 - mse: 0.0021 - accuracy: 0.8089 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8102
# Epoch 74/80
# 1563/1563 [==============================] - 43s 27ms/step - loss: 0.0021 - mse: 0.0021 - accuracy: 0.8089 - val_loss: 0.0022 - val_mse: 0.0022 - val_accuracy: 0.8083
# Epoch 75/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0021 - mse: 0.0021 - accuracy: 0.8090 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8099
# Epoch 76/80
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.0021 - mse: 0.0021 - accuracy: 0.8090 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8078
# Epoch 77/80
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.0021 - mse: 0.0021 - accuracy: 0.8091 - val_loss: 0.0022 - val_mse: 0.0022 - val_accuracy: 0.8095
# Epoch 78/80
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.0023 - mse: 0.0023 - accuracy: 0.8068 - val_loss: 0.0033 - val_mse: 0.0033 - val_accuracy: 0.8024
# Epoch 79/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0024 - mse: 0.0024 - accuracy: 0.8054 - val_loss: 0.0023 - val_mse: 0.0023 - val_accuracy: 0.8065
# Epoch 80/80
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0022 - mse: 0.0022 - accuracy: 0.8079 - val_loss: 0.0022 - val_mse: 0.0022 - val_accuracy: 0.8096

# %%
#Saving the weights and the model of the denoising model
denoised.save('/weights/denoise.h5')

denoised.save_weights('/weights/denoise_weights.h5')

predictions = denoised.predict(X_test_Blur)
display(X_test_Blur, predictions)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# We can observe that image quality is slightly denoised.

# %%
denoised.evaluate(X_test_Blur,X_test)

plot_history(hist,['mse','val_mse'])
plot_history(hist,['loss','val_loss'])
plot_history(hist,['accuracy','val_accuracy'])
# Out:
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0022 - mse: 0.0022 - accuracy: 0.8096

# %% [markdown]
# We can observe that the DnCNN model is neither overfitting nor underfitting. With mean accuracy 0.86

# %% [markdown]
# ############---------------###################

# %% [markdown]
# Now we have 2 models for deblurring DBSR and denoising DnCNN.
#
# Let the blurry and noisy image be : h
#
# Therefore, h = I*g + ϵ. where g: is the gaussian blur
#                               I: Actual image
#                               ϵ: Gaussian noise
#
# Gaussian blur g is convolved with actual image
# In the final model h is the input and I should be the expected output.
#
# So first we apply DnCNN. The resulting image should be I*g' where g' is new gaussian blur as denoising causes little bit blurring.
#
# Then we apply, DBSR and we obtain I' as output.
#
# Now we are applying fSRCNN for image restoration as I' is enhanced but contain dark patches.

# %%
denoise = load_model('/weights/denoise.h5')
load_first_model = load_model('/weights/deblur.h5')

denoise.trainable = False
load_first_model.trainable = False

input = layers.Input(shape=(32, 32, 3))
x = denoise(input,training = False) 
r = load_first_model(x, training = False)

#concat = layers.Concatenate()([input,r])
# Feature extraction layer.
x = layers.Conv2D(56, (5, 5), padding="same", activation='relu')(r)

# Shrinking layer.
x = layers.Conv2D(12, (1, 1), padding="valid", activation='relu')(x)

# Mapping layer.
for i in range(3):
  x =   layers.Conv2D(12, (3, 3), padding="same")(x)
  x =   Activation('relu')(x)
# Expanding layer.
x =  layers.Conv2D(56, (1, 1), padding="valid", activation='relu')(x) 

x = layers.Dropout(0.2)(x)
 # Deconvolution layer.
decoded = layers.Conv2DTranspose(3,(9, 9),padding='same')(x)


model = Model(input, decoded)

model.summary()

model.compile(optimizer=Adam(learning_rate = 0.002),loss='mse',metrics=['mse','accuracy'])
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  model_1 (Functional)        (None, 32, 32, 3)         561283
#
#  model (Functional)          (None, 32, 32, 3)         351043
#
#  conv2d_29 (Conv2D)          (None, 32, 32, 56)        4256
#
#  conv2d_30 (Conv2D)          (None, 32, 32, 12)        684
#
#  conv2d_31 (Conv2D)          (None, 32, 32, 12)        1308
#
#  activation_17 (Activation)  (None, 32, 32, 12)        0
#
#  conv2d_32 (Conv2D)          (None, 32, 32, 12)        1308
#
#  activation_18 (Activation)  (None, 32, 32, 12)        0
#
#  conv2d_33 (Conv2D)          (None, 32, 32, 12)        1308
#
#  activation_19 (Activation)  (None, 32, 32, 12)        0
#
#  conv2d_34 (Conv2D)          (None, 32, 32, 56)        728
#
#  dropout_1 (Dropout)         (None, 32, 32, 56)        0
#
#  conv2d_transpose_1 (Conv2DT  (None, 32, 32, 3)        13611
#  ranspose)
#
# =================================================================
# Total params: 935,529
# Trainable params: 23,203
# Non-trainable params: 912,326
# _________________________________________________________________

# %%
hist = model.fit(X_train_Blur,X_train,epochs=90,batch_size=28,shuffle=True,
    validation_data=(X_test_Blur, X_test),)
# Out:
# Epoch 1/90
# 1786/1786 [==============================] - 34s 19ms/step - loss: 0.0029 - mse: 0.0029 - accuracy: 0.8055 - val_loss: 0.0028 - val_mse: 0.0028 - val_accuracy: 0.8217
# Epoch 2/90
#  873/1786 [=============>................] - ETA: 16s - loss: 0.0028 - mse: 0.0028 - accuracy: 0.8098

# %%
model.save('/weights/final_model.h5')

model.save_weights('/weights/final_model_weights.h5')

predictions = model.predict(X_test_Blur)
display(X_test_Blur,predictions)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
model.evaluate(X_test_Blur,X_test)
# Out:
# 313/313 [==============================] - 5s 15ms/step - loss: 0.0028 - mse: 0.0028 - accuracy: 0.8230
# [0.002814311534166336, 0.002814311534166336, 0.8230190277099609]

# %% [markdown]
# The final model is not overfitting or underfitting.

# %%
plot_history(hist,['mse','val_mse'])
plot_history(hist,['loss','val_loss'])
plot_history(hist,['accuracy','val_accuracy'])
